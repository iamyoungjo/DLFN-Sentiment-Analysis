# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (40% Off: **traskud17**)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem"
#
#
# - Curate a Dataset
# - Developing a "Predictive Theory"
# - **PROJECT 1**: Quick Theory Validation
#
#
# - Transforming Text to Numbers
# - **PROJECT 2**: Creating the Input/Output Data
#
#
# - Putting it all together in a Neural Network
# - **PROJECT 3**: Building our Neural Network
#
#
# - Understanding Neural Noise
# - **PROJECT 4**: Making Learning Faster by Reducing Noise
#
#
# - Analyzing Inefficiencies in our Network
# - **PROJECT 5**: Making our Network Train and Run Faster
#
#
# - Further Noise Reduction
# - **PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary
#
#
# - Analysis: What's going on in the weights?

# %% [markdown]
# # Lesson: Curate a Dataset

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[5]
# Out:
# 'this film lacked something i couldn  t put my finger on at first charisma on the part of the leading actress . this inevitably translated to lack of chemistry when she shared the screen with her leading man . even the romantic scenes came across as being merely the actors at play . it could very well have been the director who miscalculated what he needed from the actors . i just don  t know .  br    br   but could it have been the screenplay  just exactly who was the chef in love with  he seemed more enamored of his culinary skills and restaurant  and ultimately of himself and his youthful exploits  than of anybody or anything else . he never convinced me he was in love with the princess .  br    br   i was disappointed in this movie . but  don  t forget it was nominated for an oscar  so judge for yourself .  '

# %%
labels[5]
# Out:
# 'NEGATIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %%
from collections import Counter
import numpy as np

positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

pred_label = []

for i in range(len(reviews)):
    #decision = 'POSITIVE'
    for word in reviews[i].split():
        if labels[i] == 'POSITIVE':
            positive_counts[word] += 1
            total_counts[word] += 1
        else: 
            negative_counts[word] += 1
            total_counts[word] += 1


        
#         if i is 1:
# #             print(word)
#         if word == 'terrible':
#             decision = 'NEGATIVE'
#         elif word == 'improbable':
#             decision = 'NEGATIVE'
#         elif word == 'horrible':
#             decision = 'NEGATIVE'
#         elif word == 'sucks':
#             decision = 'NEGATIVE'
    
#    pred_label.append(decision)


#print(positive_counts.most_common())
# correct_count = 0
# for i in range(len(reviews)):
#     if pred_label[i] == labels[i]:
#         correct_count += 1

# print(correct_count/len(reviews))

# %%
pos_neg_ratio = Counter()

for word, cnt in total_counts.items():
    if cnt > 10:
        pos_neg_ratio[word] = positive_counts[word] / (negative_counts[word]+1)
        
        

#print(pos_neg_ratio.most_common())
# Out:
# [('edie', 109.0), ('antwone', 88.0), ('din', 82.0), ('gunga', 66.0), ('goldsworthy', 65.0), ('yokai', 60.0), ('gypo', 60.0), ('paulie', 59.0), ('flavia', 51.0), ('visconti', 51.0), ('blandings', 48.0), ('kells', 48.0), ('brashear', 47.0), ('gino', 46.0), ('deathtrap', 45.0), ('panahi', 41.0), ('harilal', 41.0), ('ossessione', 39.0), ('caruso', 38.0), ('tsui', 38.0), ('ahmad', 37.0), ('sabu', 37.0), ('dominick', 36.0), ('khouri', 36.0), ('mj', 35.0), ('aweigh', 35.0), ('mcintire', 34.0), ('kriemhild', 34.0), ('blackie', 33.0), ('newcombe', 33.0), ('daisies', 33.0), ('kei', 32.0), ('trelkovsky', 32.0), ('jaffar', 31.0), ('hilliard', 31.0), ('gundam', 30.666666666666668), ('pazu', 30.0), ('bathsheba', 30.0), ('offside', 30.0), ('sheeta', 30.0), ('krell', 30.0), ('fineman', 29.0), ('venoms', 29.0), ('ranma', 28.0), ('ronny', 28.0), ('paine', 28.0), ('pimlico', 28.0), ('abhay', 27.0), ('iturbi', 26.5), ('pym', 26.0), ('kipling', 26.0), ('kelso', 25.0), ('milverton', 25.0), ('gabe', 25.0), ('audiard', 25.0), ('scalise', 25.0), ('mukhsin', 24.0), ('moonwalker', 24.0), ('grisby', 24.0), ('xica', 24.0), ('giovanna', 24.0), ('feinstone', 24.0), ('felix', 23.4), ('togar', 23.0), ('jannings', 23.0), ('chikatilo', 23.0), ('heaton', 23.0), ('luzhin', 22.5), ('miklos', 22.0), ('soha', 22.0), ('pidgeon', 22.0), ('desdemona', 22.0), ('fanfan', 22.0), ('leonora', 22.0), ('matuschek', 22.0), ('matador', 22.0), ('philo', 21.5), ('gauri', 21.0), ('lindy', 21.0), ('joss', 21.0), ('bjm', 21.0), ('reda', 21.0), ('maradona', 21.0), ('firemen', 21.0), ('microfilm', 21.0), ('capote', 20.333333333333332), ('fido', 20.25), ('prote', 20.0), ('coonskin', 20.0), ('quibble', 20.0), ('siegfried', 20.0), ('emory', 20.0), ('coe', 20.0), ('mcintyre', 20.0), ('carrre', 20.0), ('excellently', 19.666666666666668), ('clutter', 19.5), ('pakeezah', 19.0), ('petiot', 19.0), ('ackland', 19.0), ('magnus', 19.0), ('baloo', 19.0), ('malfique', 19.0), ('flippen', 19.0), ('anchors', 19.0), ('rvd', 19.0), ('hillyer', 19.0), ('pinjar', 19.0), ('railly', 19.0), ('burakov', 19.0), ('vance', 19.0), ('versatility', 19.0), ('digicorp', 19.0), ('ferdie', 19.0), ('schlesinger', 19.0), ('knockout', 19.0), ('kolchak', 18.75), ('hayworth', 18.666666666666668), ('deanna', 18.666666666666668), ('pollak', 18.0), ('lando', 18.0), ('geer', 18.0), ('iphigenia', 18.0), ('guerrero', 18.0), ('hobson', 18.0), ('falco', 18.0), ('volckman', 18.0), ('burgade', 18.0), ('iek', 18.0), ('pappas', 18.0), ('hoechlin', 18.0), ('korda', 17.5), ('sammo', 17.333333333333332), ('toughness', 17.0), ('peralta', 17.0), ('orked', 17.0), ('cdric', 17.0), ('nighy', 17.0), ('naudet', 17.0), ('callahan', 17.0), ('laputa', 17.0), ('sox', 17.0), ('beckett', 17.0), ('nagra', 17.0), ('kralik', 17.0), ('jeon', 17.0), ('biko', 17.0), ('jacknife', 17.0), ('hewlett', 17.0), ('polanski', 16.833333333333332), ('alvin', 16.75), ('matthau', 16.555555555555557), ('aiello', 16.5), ('janos', 16.0), ('duffell', 16.0), ('macready', 16.0), ('gaiman', 16.0), ('antz', 16.0), ('santos', 16.0), ('mathieu', 16.0), ('endor', 16.0), ('firefighter', 16.0), ('coulouris', 16.0), ('bedknobs', 16.0), ('delpy', 16.0), ('bombshells', 16.0), ('rotj', 16.0), ('hulce', 16.0), ('yvaine', 16.0), ('natalia', 16.0), ('adele', 15.666666666666666), ('myrtle', 15.666666666666666), ('gackt', 15.666666666666666), ('bake', 15.5), ('gilliam', 15.25), ('silberling', 15.0), ('bernsen', 15.0), ('burman', 15.0), ('uld', 15.0), ('ballantine', 15.0), ('calamai', 15.0), ('shintaro', 15.0), ('egon', 15.0), ('johnnie', 15.0), ('grasshoppers', 15.0), ('mcanally', 15.0), ('cognac', 15.0), ('rotoscoped', 15.0), ('hickock', 15.0), ('goines', 15.0), ('eustache', 15.0), ('parador', 15.0), ('valette', 15.0), ('oro', 15.0), ('cheh', 15.0), ('baton', 15.0), ('lian', 15.0), ('aviv', 15.0), ('hilda', 15.0), ('kiley', 15.0), ('schildkraut', 15.0), ('ashraf', 15.0), ('gannon', 15.0), ('soutendijk', 15.0), ('doktor', 15.0), ('karas', 15.0), ('lanisha', 15.0), ('gunbuster', 15.0), ('vict ...
